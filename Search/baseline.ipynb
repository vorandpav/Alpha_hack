# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Загрузка данных.

# %%
# Очищенный датасет вопросов
questions_clear = pd.read_csv('../Data/Processed/Questions.csv', encoding='latin1')
# Выводим первые 5 строк
questions_clear.head()
# Out:
#     Id  OwnerUserId          CreationDate            ClosedDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z                   NaN     26
# 1   90         58.0  2008-08-01T14:41:24Z  2012-12-26T03:45:49Z    144
# 2  120         83.0  2008-08-01T15:50:08Z                   NaN     21
# 3  180    2089740.0  2008-08-01T18:42:19Z                   NaN     53
# 4  260         91.0  2008-08-01T23:22:08Z                   NaN     49
#
#                                                Title  \
# 0  SQLStatement.execute() - multiple queries in o...
# 1  Good branching and merging tutorials for Torto...
# 2                                  ASP.NET Site Maps
# 3                 Function for creating color wheels
# 4  Adding scripting functionality to .NET applica...
#
#                                                 Body
# 0  write database generation script sql want exec...
# 1  really good tutorial explain branching merge a...
# 2  anyone get experience create sqlbased aspnet s...
# 3  something pseudosolved many time never quite f...
# 4  little game write c us database backend tradin...

# %%
# Очищенный датасет ответов
answers_clear = pd.read_csv('../Data/Processed/Answers.csv', encoding='latin1')
# Выводим первые 5 строк
answers_clear.head()
# Out:
#     Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0   92         61.0  2008-08-01T14:45:37Z        90     13
# 1  124         26.0  2008-08-01T16:09:47Z        80     12
# 2  199         50.0  2008-08-01T19:36:46Z       180      1
# 3  269         91.0  2008-08-01T23:49:57Z       260      4
# 4  307         49.0  2008-08-02T01:49:46Z       260     28
#
#                                                 Body
# 0  version control subversion good resource sourc...
# 1  wound use kind hack actually work pretty well ...
# 2  read somewhere human eye distinguish less 4 va...
# 3  yes thought soon figure another domainspecific...
# 4  oleg shilos c script solution code project rea...

# %% [markdown]
# ## Генерация эмбеддингов

# %%
# Находим Id лучшего ответа для каждого вопроса
best_answers_clear = answers_clear.loc[answers_clear.groupby('ParentId')['Score'].idxmax()]

# Объединяем с вопросами (inner join)
merged = pd.merge(
    questions_clear[['Id', 'Title', 'Body', 'Score', 'CreationDate']],
    best_answers_clear[['ParentId', 'Body', 'Score', 'CreationDate']],
    left_on='Id',
    right_on='ParentId',
    suffixes=('_question', '_answer')
)

# Заменяем Nan в ответах на пустую строку
merged['Body_answer'] = merged['Body_answer'].fillna('')
# Заменяем Nan в вопросах на пустую строку
merged['Body_question'] = merged['Body_question'].fillna('')

# Собираем единый текст для эмбеддинга: вопрос + ответ
merged['text'] = merged['Body_question'] + ' ' + merged['Body_answer']

merged['text']
# Out:
# 0          write database generation script sql want exec...
# 1          really good tutorial explain branching merge a...
# 2          anyone get experience create sqlbased aspnet s...
# 3          something pseudosolved many time never quite f...
# 4          little game write c us database backend tradin...
#                                  ...
# 1102563    around 200000 data excel separate per 15min da...
# 1102564    able connect linkedin api two month everything...
# 1102565    building multitenant app rail 4 apartment devi...
# 1102566    learn c try draw iscosceles triangle use aster...
# 1102567    need extend shell script bash much familiar py...
# Name: text, Length: 1102568, dtype: object

# %%
import torch
from sentence_transformers import SentenceTransformer
from tqdm.notebook import tqdm

# Проверяем доступность GPU
gpu_info = torch.cuda.get_device_properties(0)
print(f"GPU: {gpu_info.name}, Memory: {gpu_info.total_memory // (1024 ** 2)} MB")
# Out:
# GPU: NVIDIA GeForce RTX 4060, Memory: 8187 MB

# %%
# Задаем модель
model_name = 'all-MiniLM-L6-v2'
model = SentenceTransformer(model_name)
model = model.half()  # Ускоряет в два раза, но убирает точность до 4 знаков

texts = merged['text'].tolist()
batch_size = 4096  # размер батча

embeddings = []

with torch.no_grad():
    for start in tqdm(range(0, len(texts), batch_size), desc="Calculating embeddings"):
        batch = texts[start:start + batch_size]
        emb = model.encode(
            batch,
            device='cuda',
            show_progress_bar=False,
            convert_to_numpy=True,  # быстрее и меньше памяти
            num_workers=12,  # количество потоков для обработки
        )
        embeddings.append(emb)

# Склеиваем батчи в одну матрицу
emb_matrix = np.vstack(embeddings)

print(f"Эмбеддинги рассчитаны: {emb_matrix.shape[0]} объектов, размерность {emb_matrix.shape[1]}")
# Out:
# Calculating embeddings:   0%|          | 0/270 [00:00<?, ?it/s]
# Эмбеддинги рассчитаны: 1102568 объектов, размерность 384

# %%
# Сохраняем эмбеддинги в файл
np.save('../Data/Embeddings/embeddings.npy', emb_matrix)

# %%
# Загружаем эмбеддинги из файла
emb_matrix = np.load('../Data/Embeddings/embeddings.npy')
print(f"Эмбеддинги загружены: {emb_matrix.shape[0]} объектов, размерность {emb_matrix.shape[1]}")
# Out:
# Эмбеддинги загружены: 1102568 объектов, размерность 384

# %% [markdown]
# ## Развертывание Chroma DB

# %%
# Удаляем из merged Body_question и Body_answer
merged = merged.drop(columns=['Body_question', 'Body_answer'])
merged
# Out:
#                Id                                              Title  \
# 0              80  SQLStatement.execute() - multiple queries in o...
# 1              90  Good branching and merging tutorials for Torto...
# 2             120                                  ASP.NET Site Maps
# 3             180                 Function for creating color wheels
# 4             260  Adding scripting functionality to .NET applica...
# ...           ...                                                ...
# 1102563  40142860                         Adding large data in Excel
# 1102564  40142900  LinkedIN Encounter error: Your application has...
# 1102565  40142910  Validation for must_be_below_user_limit allowi...
# 1102566  40142940  Drawing an iscosceles triangle of asteriks on C++
# 1102567  40143190  How to execute multiline python code from a ba...
#
#          Score_question CreationDate_question  ParentId  Score_answer  \
# 0                    26  2008-08-01T13:57:07Z        80            12
# 1                   144  2008-08-01T14:41:24Z        90            19
# 2                    21  2008-08-01T15:50:08Z       120             9
# 3                    53  2008-08-01T18:42:19Z       180            21
# 4                    49  2008-08-01T23:22:08Z       260            28
# ...                 ...                   ...       ...           ...
# 1102563               0  2016-10-19T23:01:07Z  40142860             0
# 1102564               0  2016-10-19T23:05:07Z  40142900             0
# 1102565               0  2016-10-19T23:05:49Z  40142910             0
# 1102566              -1  2016-10-19T23:08:42Z  40142940             1
# 1102567               1  2016-10-19T23:36:01Z  40143190             5
#
#           CreationDate_answer  \
# 0        2008-08-01T16:09:47Z
# 1        2009-09-23T15:40:46Z
# 2        2008-09-23T22:41:11Z
# 3        2008-08-02T19:03:52Z
# 4        2008-08-02T01:49:46Z
# ...                       ...
# 1102563  2016-10-19T23:14:50Z
# 1102564  2016-10-19T23:16:10Z
# 1102565  2016-10-19T23:58:58Z
# 1102566  2016-10-19T23:30:12Z
# 1102567  2016-10-19T23:38:17Z
#
#                                                       text
# 0        write database generation script sql want exec...
# 1        really good tutorial explain branching merge a...
# 2        anyone get experience create sqlbased aspnet s...
# 3        something pseudosolved many time never quite f...
# 4        little game write c us database backend tradin...
# ...                                                    ...
# 1102563  around 200000 data excel separate per 15min da...
# 1102564  able connect linkedin api two month everything...
# 1102565  building multitenant app rail 4 apartment devi...
# 1102566  learn c try draw iscosceles triangle use aster...
# 1102567  need extend shell script bash much familiar py...
#
# [1102568 rows x 8 columns]

# %%
# Присоединяем эмбеддинги к merged
merged['embeddings'] = list(emb_matrix)
merged
# Out:
#                Id                                              Title  \
# 0              80  SQLStatement.execute() - multiple queries in o...
# 1              90  Good branching and merging tutorials for Torto...
# 2             120                                  ASP.NET Site Maps
# 3             180                 Function for creating color wheels
# 4             260  Adding scripting functionality to .NET applica...
# ...           ...                                                ...
# 1102563  40142860                         Adding large data in Excel
# 1102564  40142900  LinkedIN Encounter error: Your application has...
# 1102565  40142910  Validation for must_be_below_user_limit allowi...
# 1102566  40142940  Drawing an iscosceles triangle of asteriks on C++
# 1102567  40143190  How to execute multiline python code from a ba...
#
#          Score_question CreationDate_question  ParentId  Score_answer  \
# 0                    26  2008-08-01T13:57:07Z        80            12
# 1                   144  2008-08-01T14:41:24Z        90            19
# 2                    21  2008-08-01T15:50:08Z       120             9
# 3                    53  2008-08-01T18:42:19Z       180            21
# 4                    49  2008-08-01T23:22:08Z       260            28
# ...                 ...                   ...       ...           ...
# 1102563               0  2016-10-19T23:01:07Z  40142860             0
# 1102564               0  2016-10-19T23:05:07Z  40142900             0
# 1102565               0  2016-10-19T23:05:49Z  40142910             0
# 1102566              -1  2016-10-19T23:08:42Z  40142940             1
# 1102567               1  2016-10-19T23:36:01Z  40143190             5
#
#           CreationDate_answer  \
# 0        2008-08-01T16:09:47Z
# 1        2009-09-23T15:40:46Z
# 2        2008-09-23T22:41:11Z
# 3        2008-08-02T19:03:52Z
# 4        2008-08-02T01:49:46Z
# ...                       ...
# 1102563  2016-10-19T23:14:50Z
# 1102564  2016-10-19T23:16:10Z
# 1102565  2016-10-19T23:58:58Z
# 1102566  2016-10-19T23:30:12Z
# 1102567  2016-10-19T23:38:17Z
#
#                                                       text  \
# 0        write database generation script sql want exec...
# 1        really good tutorial explain branching merge a...
# 2        anyone get experience create sqlbased aspnet s...
# 3        something pseudosolved many time never quite f...
# 4        little game write c us database backend tradin...
# ...                                                    ...
# 1102563  around 200000 data excel separate per 15min da...
# 1102564  able connect linkedin api two month everything...
# 1102565  building multitenant app rail 4 apartment devi...
# 1102566  learn c try draw iscosceles triangle use aster...
# 1102567  need extend shell script bash much familiar py...
#
#                                                 embeddings
# 0        [0.01357938, -0.024715697, -0.056818295, 0.089...
# 1        [0.022999706, -0.054095984, -0.04250651, -0.07...
# 2        [0.002508051, -0.064242, -0.015580753, 0.00925...
# 3        [0.009283214, 0.027419629, -0.014058785, -0.06...
# 4        [-0.015197881, -0.029962653, -0.12446398, 0.04...
# ...                                                    ...
# 1102563  [-0.041066702, 0.094635084, 0.016694594, 0.017...
# 1102564  [-0.07177593, -0.01753621, 0.07370899, -0.0023...
# 1102565  [0.0020394926, -0.033933215, -0.04788427, -0.0...
# 1102566  [0.0074667125, 0.11854785, -0.06675289, -0.068...
# 1102567  [-0.0038164519, 0.040050633, -0.030023957, 0.0...
#
# [1102568 rows x 9 columns]

# %%
# Переименовываем столбцы
merged = merged.rename(columns={
    'text': 'Clean_text',
    'Title': 'Title',
    'Score': 'Score_question',
    'CreationDate': 'CreationDate_question',
    'Score_answer': 'Score_answer'
})
merged
# Out:
#                Id                                              Title  \
# 0              80  SQLStatement.execute() - multiple queries in o...
# 1              90  Good branching and merging tutorials for Torto...
# 2             120                                  ASP.NET Site Maps
# 3             180                 Function for creating color wheels
# 4             260  Adding scripting functionality to .NET applica...
# ...           ...                                                ...
# 1102563  40142860                         Adding large data in Excel
# 1102564  40142900  LinkedIN Encounter error: Your application has...
# 1102565  40142910  Validation for must_be_below_user_limit allowi...
# 1102566  40142940  Drawing an iscosceles triangle of asteriks on C++
# 1102567  40143190  How to execute multiline python code from a ba...
#
#          Score_question CreationDate_question  ParentId  Score_answer  \
# 0                    26  2008-08-01T13:57:07Z        80            12
# 1                   144  2008-08-01T14:41:24Z        90            19
# 2                    21  2008-08-01T15:50:08Z       120             9
# 3                    53  2008-08-01T18:42:19Z       180            21
# 4                    49  2008-08-01T23:22:08Z       260            28
# ...                 ...                   ...       ...           ...
# 1102563               0  2016-10-19T23:01:07Z  40142860             0
# 1102564               0  2016-10-19T23:05:07Z  40142900             0
# 1102565               0  2016-10-19T23:05:49Z  40142910             0
# 1102566              -1  2016-10-19T23:08:42Z  40142940             1
# 1102567               1  2016-10-19T23:36:01Z  40143190             5
#
#           CreationDate_answer  \
# 0        2008-08-01T16:09:47Z
# 1        2009-09-23T15:40:46Z
# 2        2008-09-23T22:41:11Z
# 3        2008-08-02T19:03:52Z
# 4        2008-08-02T01:49:46Z
# ...                       ...
# 1102563  2016-10-19T23:14:50Z
# 1102564  2016-10-19T23:16:10Z
# 1102565  2016-10-19T23:58:58Z
# 1102566  2016-10-19T23:30:12Z
# 1102567  2016-10-19T23:38:17Z
#
#                                                 Clean_text  \
# 0        write database generation script sql want exec...
# 1        really good tutorial explain branching merge a...
# 2        anyone get experience create sqlbased aspnet s...
# 3        something pseudosolved many time never quite f...
# 4        little game write c us database backend tradin...
# ...                                                    ...
# 1102563  around 200000 data excel separate per 15min da...
# 1102564  able connect linkedin api two month everything...
# 1102565  building multitenant app rail 4 apartment devi...
# 1102566  learn c try draw iscosceles triangle use aster...
# 1102567  need extend shell script bash much familiar py...
#
#                                                 embeddings
# 0        [0.01357938, -0.024715697, -0.056818295, 0.089...
# 1        [0.022999706, -0.054095984, -0.04250651, -0.07...
# 2        [0.002508051, -0.064242, -0.015580753, 0.00925...
# 3        [0.009283214, 0.027419629, -0.014058785, -0.06...
# 4        [-0.015197881, -0.029962653, -0.12446398, 0.04...
# ...                                                    ...
# 1102563  [-0.041066702, 0.094635084, 0.016694594, 0.017...
# 1102564  [-0.07177593, -0.01753621, 0.07370899, -0.0023...
# 1102565  [0.0020394926, -0.033933215, -0.04788427, -0.0...
# 1102566  [0.0074667125, 0.11854785, -0.06675289, -0.068...
# 1102567  [-0.0038164519, 0.040050633, -0.030023957, 0.0...
#
# [1102568 rows x 9 columns]

# %%
# Удалим все кроме merged
del questions_clear
del answers_clear
del best_answers_clear
del emb_matrix

import gc
gc.collect()
# Out:
# 239

# %%
import chromadb
from chromadb.config import Settings
import uuid
from tqdm.notebook import tqdm

# Инициализация Chroma
chroma_client = chromadb.Client(Settings(
    persist_directory="./chroma_data"  # Папка для хранения данных
))

# Создание новой коллекции
collection = chroma_client.create_collection(
    name="Alpha",
    metadata={"hnsw:space": "cosine"}  # Используем косинусное расстояние
)

# Добавляем документы в коллекцию
batch_size = 1000  # Размер батча

for i in tqdm(range(0, len(merged), batch_size), desc="Adding documents to Chroma"):
    batch = merged.iloc[i:i + batch_size]
    # Генерируем уникальные идентификаторы
    ids = [str(uuid.uuid4()) for _ in range(len(batch))]

    # Добавляем документы в коллекцию
    collection.add(
        documents=batch['Clean_text'].tolist(),
        metadatas=batch[
            ['Id', 'ParentId', 'Title', 'Score_question', 'CreationDate_question', 'Score_answer']].to_dict(
            orient='records'),
        embeddings=batch['embeddings'].tolist(),
        ids=ids
    )

# Проверяем количество документов в коллекции
print(f"Всего документов в коллекции: {collection.count()}")
# Out:
# Adding documents to Chroma:   0%|          | 0/1103 [00:00<?, ?it/s]
# Всего документов в коллекции: 1102568

# %%
# Удаляем коллекцию
# chroma_client.delete_collection("Alpha")

# %%
# Удаляем merged
del merged

gc.collect()
# Out:
# 0

# %% [markdown]
# ## Реализация семантического поиска

# %%
# Очистка текста
import re
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')  # Загрузка стоп-слов
nltk.download('wordnet')  # Загрузка WordNet
nltk.download('averaged_perceptron_tagger_eng')  # Загрузка тегов
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\VORANDPAV BIG
# [nltk_data]     SPB\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\VORANDPAV BIG
# [nltk_data]     SPB\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\VORANDPAV BIG
# [nltk_data]     SPB\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
stop_words = set(stopwords.words('english'))  # Загрузка стоп-слов
contractions = ['ive', 'youre', 'theyre', 'hes', 'shes', 'its', 'weve', 'theyve', 'im', 'isnt', 'wasnt', 'werent',
                'hasnt', 'havent', 'dont', 'doesnt', 'didnt', 'cant', 'couldnt', 'shouldnt', 'mightnt', 'mustnt',
                'wouldnt']  # Список сокращений
lemmatizer = WordNetLemmatizer()  # Загрузка лемматизатора


# Функция опеределения части речи для лемматизации
def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {
        'J': wordnet.ADJ,
        'N': wordnet.NOUN,
        'V': wordnet.VERB,
        'R': wordnet.ADV
    }
    return tag_dict.get(tag, wordnet.NOUN)


# Функция для очистки текста
def clean_text(text):
    if not isinstance(text, str):  # Проверяем, что текст является строкой
        return ''

    text = re.sub(r'<code>.*?</code>', '', text, flags=re.DOTALL)  # Удаляем блоки <code>
    text = re.sub(r'\`[^\`]*\`', '', text)  # Удаляем инлайн-код в Markdown
    text = re.sub(r'<[^>]*>', '', text)  # Удаляем оставшиеся HTML-теги
    text = re.sub(r'\[.*?\]\(.*?\)', '', text)  # Удаляем Markdown-ссылки
    text = re.sub(r'"[^"]*"', '', text)  # Удаляем текст в кавычках
    text = re.sub(r'\s+', ' ', text).strip()  # Удаляем лишние пробелы

    text = text.lower()  # Приводим текст к нижнему регистру
    text = re.sub(r'[^a-z0-9\s]', '', text)  # Удаляем все кроме букв, цифр и пробелов

    words = text.split()  # Разбиваем текст на слова
    words = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in words if
             word not in stop_words and word not in contractions]  # Удаляем стоп-слова и сокращения, лемматизируем слова
    text = ' '.join(words)  # Объединяем слова обратно в текст

    return text

# %%
# Загружаем модель
from sentence_transformers import SentenceTransformer

model_name = 'all-MiniLM-L6-v2'
model = SentenceTransformer(model_name)


def semantic_search(query, top_k=5):
    """
    Функция для семантического поиска в Chroma
    :param query: текст запроса
    :param top_k: количество ближайших соседей
    :return: список найденных документов
    """
    # Очищаем текст запроса
    query = clean_text(query)

    # Вычисляем эмбеддинг запроса
    query_embedding = model.encode(
        [query],
        device='cuda',
        show_progress_bar=False,
        convert_to_numpy=True,
        num_workers=12,
    )[0]

    # Выполняем поиск ближайших соседей
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=top_k
    )

    return results

# %% [markdown]
# ## Тестирование семантического поиска

# %%
# Пример поиска
# Лучший ответ совпал с 4 лабой - правильный ответ
query = "<p>I've written a database generation script in <a href=""http://en.wikipedia.org/wiki/SQL"">SQL</a> and want to execute it in my <a href=""http://en.wikipedia.org/wiki/Adobe_Integrated_Runtime"">Adobe AIR</a> application:</p>"
top_results = semantic_search(query, top_k=5)
top_results
# Out:
# {'ids': [['236dcf46-0fde-43d3-9559-c44b199c111a',
#    '04c1c460-9482-4a10-8e5b-a6446039ee5a',
#    'b6d8bef2-2b52-4a3d-b5ea-7d6b58e2c925',
#    '08037cac-4522-48ea-a264-372217f11ccf',
#    'ce303ff3-cb9a-47ef-bdad-086bf8a24ff5']],
#  'embeddings': None,
#  'documents': [['write database generation script sql want execute adobe air application execute adobe air use follow method error generate however exists seem look first query semicolon remove query fails way call multiple query one statement wound use kind hack actually work pretty well thing careful semicolon',
#    'whenever try create one table actionscript first one get run use string query embed external file sql code every time seem ignore everything first perhaps feature actionscript deal database add table separate query way get around like idea whole db create statement set one contain place seem multiple statement arent support air sqlite command might separate script statement execute sequentially',
#    'would like create database table sm generate script c create table programmitically currently hand cod table time visual studio think far well create table sql management studio generate script c execute latter guy idea sql management studio 2008 right click database select task option generate script option wizard walk generate script script whatever need database use script c create tablesprocedureswhatever edit follow chunk code execute sql script go statement sql 2008 anyway',
#    'want generate create table script already create table database know generate script use right click table click script table menu script generate want execute use ssis package need generate script file modify database want process use sql query way try one output',
#    'database create use sql server developer 2008 want script file recreate anyone time idea follow step pinals site careful select option want httpblogsqlauthoritycom20070821sqlserver2005createscripttocopydatabaseschemaandalltheobjectsstoredprocedurefunctionstriggerstablesviewsconstraintsandallotherdatabaseobjects']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'CreationDate_question': '2008-08-01T13:57:07Z',
#     'Score_question': 26,
#     'ParentId': 80,
#     'Id': 80,
#     'Score_answer': 12,
#     'Title': 'SQLStatement.execute() - multiple queries in one statement'},
#    {'ParentId': 5189850,
#     'Score_question': 2,
#     'CreationDate_question': '2011-03-04T04:56:48Z',
#     'Id': 5189850,
#     'Score_answer': 2,
#     'Title': 'Can I create more than 1 table at a time in a SQLite query in Actionscript?'},
#    {'Score_question': 1,
#     'Title': 'How to generate scripts using SQL management studio for C# Usage',
#     'Score_answer': 0,
#     'CreationDate_question': '2010-03-30T22:45:30Z',
#     'ParentId': 2549240,
#     'Id': 2549240},
#    {'ParentId': 20884660,
#     'Score_answer': 5,
#     'Id': 20884660,
#     'Title': 'How to generate create script of tables with their constraints using SQL query in SQL Server 2008',
#     'Score_question': 3,
#     'CreationDate_question': '2014-01-02T14:01:11Z'},
#    {'Id': 832320,
#     'CreationDate_question': '2009-05-06T23:49:32Z',
#     'Score_question': 1,
#     'Title': 'How Do I Script a Database To a Text File So That It Can Be Created Again By Anyone?',
#     'ParentId': 832320,
#     'Score_answer': 1}]],
#  'distances': [[0.21899890899658203,
#    0.2852456569671631,
#    0.37567436695098877,
#    0.3853175640106201,
#    0.40269935131073]]}

# %%
# Пример поиска
# Похожий вопрос, но не тот же самый
# Результат - 2 ответ
query = "<p>I've made a database maker script in <a href=""http://en.wikipedia.org/wiki/SQL"">SQL</a> and want to use it in my <a href=""http://en.wikipedia.org/wiki/Adobe_Integrated_Runtime"">Adobe AIR</a> application:</p>"
top_results = semantic_search(query, top_k=5)
top_results
# Out:
# {'ids': [['04c1c460-9482-4a10-8e5b-a6446039ee5a',
#    '236dcf46-0fde-43d3-9559-c44b199c111a',
#    'b6d8bef2-2b52-4a3d-b5ea-7d6b58e2c925',
#    'ce303ff3-cb9a-47ef-bdad-086bf8a24ff5',
#    '6faf4b3e-ecfb-4253-bc2f-8cfb73bc543f']],
#  'embeddings': None,
#  'documents': [['whenever try create one table actionscript first one get run use string query embed external file sql code every time seem ignore everything first perhaps feature actionscript deal database add table separate query way get around like idea whole db create statement set one contain place seem multiple statement arent support air sqlite command might separate script statement execute sequentially',
#    'write database generation script sql want execute adobe air application execute adobe air use follow method error generate however exists seem look first query semicolon remove query fails way call multiple query one statement wound use kind hack actually work pretty well thing careful semicolon',
#    'would like create database table sm generate script c create table programmitically currently hand cod table time visual studio think far well create table sql management studio generate script c execute latter guy idea sql management studio 2008 right click database select task option generate script option wizard walk generate script script whatever need database use script c create tablesprocedureswhatever edit follow chunk code execute sql script go statement sql 2008 anyway',
#    'database create use sql server developer 2008 want script file recreate anyone time idea follow step pinals site careful select option want httpblogsqlauthoritycom20070821sqlserver2005createscripttocopydatabaseschemaandalltheobjectsstoredprocedurefunctionstriggerstablesviewsconstraintsandallotherdatabaseobjects',
#    'know command create database sqlite ie anybody tell command open exist database terminal please anybody help simply use']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'Id': 5189850,
#     'ParentId': 5189850,
#     'CreationDate_question': '2011-03-04T04:56:48Z',
#     'Score_question': 2,
#     'Score_answer': 2,
#     'Title': 'Can I create more than 1 table at a time in a SQLite query in Actionscript?'},
#    {'ParentId': 80,
#     'Score_answer': 12,
#     'Score_question': 26,
#     'CreationDate_question': '2008-08-01T13:57:07Z',
#     'Title': 'SQLStatement.execute() - multiple queries in one statement',
#     'Id': 80},
#    {'Score_question': 1,
#     'Title': 'How to generate scripts using SQL management studio for C# Usage',
#     'Score_answer': 0,
#     'Id': 2549240,
#     'CreationDate_question': '2010-03-30T22:45:30Z',
#     'ParentId': 2549240},
#    {'Id': 832320,
#     'Title': 'How Do I Script a Database To a Text File So That It Can Be Created Again By Anyone?',
#     'Score_answer': 1,
#     'ParentId': 832320,
#     'CreationDate_question': '2009-05-06T23:49:32Z',
#     'Score_question': 1},
#    {'Title': 'command to open an existing sqlite database',
#     'Score_question': 0,
#     'Score_answer': 5,
#     'CreationDate_question': '2011-03-31T05:57:55Z',
#     'ParentId': 5495830,
#     'Id': 5495830}]],
#  'distances': [[0.2700650691986084,
#    0.2743297815322876,
#    0.37728172540664673,
#    0.4053812623023987,
#    0.41697388887405396]]}

# %%
# Пример поиска
# Ни один ответ не совпал с 4 лабой - неправильный ответ
query = "<p>I am porting the unity game in windows store game so have generated the windows store build from unity4.2.2 when i build the unity build solution from visual studio 2013 on windows 8.1 platform (retargetted the solution to 8.1 ) i am getting error at following line in AppManifest.xml</p>"
top_results = semantic_search(query, top_k=5)
top_results
# Out:
# {'ids': [['f553d986-9473-4093-babb-1ee25283e41f',
#    'bac7bac5-e5c6-41b3-917d-be87f8a4fab1',
#    'eb2ba2e5-9353-4e4f-9cc6-b65d56620ab5',
#    'dd6f683a-804a-4a6c-990c-732610a16e6d',
#    '6e1645fe-1582-4b86-8c25-daf638a29c0b']],
#  'embeddings': None,
#  'documents': [['use unity 531f1 vs2015 update 1 try export project window 10 universal xaml even try d3d get 300 error able run blank windows10 universal app create use vs2015 try reinstall update vs2015unity game work export window 881 platformwebgl window desktop edit go toolsoptionsnuget package manager tick allow nuget download miss package tick automatically check miss package build v',
#    'visual studio 2013 solution include window 81 winjs app along mvc web application build solution locally visual studio work fine building build server fails follow error getsolutionconfigurationcontents could software versioning issue local environment instal build server idea would helpful track thanks problem packageappxmanifest file packaging tab set option set fix issue build successful update problem reoccurred target x64 build keep project set',
#    'update visual studio 2013 update 2 create window store 80 apps anymore time try window store 81 app easy create new 81 project remove follow line csproj file reopen file voila window 8 project',
#    'try create new window universal app uwp new project seem broken use visual studio 2015 rc version 4600076 net window store apps 4510 use simple way next try build project without modify nothing project get error severity code description project file line error cs0535 mainpage implement interface member icomponentconnector2connectint object object dwindows phoneobjx86debugmainpagegcs 16 find solution internet maybe problem net version assembly miss someone error fix try visual studio installation nothing new happen try remove visual studio install first time make custom installation time make full installation seem work good strange bug',
#    'universal project target window store 81 window phone 81 platform window one work fine trouble run wp one emulator get error message say microsoft visual studio unable activate window store app numbershereapp kisswindowsphoneexe process start activation request fail error msg polish app start window would check system event log see log error dll system try load help lot debug similar problem window store project clue check exactly load bad part create package appx checked dlls packed exe seem include dependency app explicility us yet something still miss might hidden dependency one dlls idea debug issue emulator due wic code app andor call cocreateinstance window phone environment pc work flawlessly though']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'Score_question': 1,
#     'Title': 'Windows 10 Universal errors unity3d',
#     'Id': 34379500,
#     'Score_answer': 1,
#     'ParentId': 34379500,
#     'CreationDate_question': '2015-12-20T09:14:07Z'},
#    {'CreationDate_question': '2014-05-21T00:01:13Z',
#     'Score_answer': 1,
#     'ParentId': 23771870,
#     'Title': 'The target "GetSolutionConfigurationContents" does not exist in the project',
#     'Score_question': 0,
#     'Id': 23771870},
#    {'Score_question': 0,
#     'Score_answer': 3,
#     'Title': 'targeting windows store 8.0 with visual studio 2013 update 2',
#     'CreationDate_question': '2014-04-03T17:25:13Z',
#     'ParentId': 22844780,
#     'Id': 22844780},
#    {'ParentId': 30765290,
#     'Id': 30765290,
#     'Score_question': 0,
#     'Title': 'does not implement interface member IComponentConnector2',
#     'CreationDate_question': '2015-06-10T19:13:44Z',
#     'Score_answer': 0},
#    {'Score_answer': 0,
#     'ParentId': 26590280,
#     'Id': 26590280,
#     'CreationDate_question': '2014-10-27T14:51:00Z',
#     'Score_question': 2,
#     'Title': 'Error running app on Windows Phone 8.1 emulator - A dependent dll was not found'}]],
#  'distances': [[0.3506168723106384,
#    0.3777308464050293,
#    0.3893105983734131,
#    0.39452725648880005,
#    0.39626872539520264]]}

# %%
# Пример поиска
# Лучший ответ совпал с 4 лабой - правильный ответ
query = "I am building a test for an MVC5 controller method.  I'm using moq for the test.  What I'm interested in is how to test a controller method that requires authentication and uses the userid value not the username value to make decisions about what data to show to the browser/client."
top_results = semantic_search(query, top_k=5)
top_results
# Out:
# {'ids': [['6eed49f7-c4c5-44af-a3bb-2450d2ca0e03',
#    '993a25e9-9f78-45a3-8d3a-5ed4daffad38',
#    '21c77ef1-beb6-4d2f-b706-469bf8d5a658',
#    '0b36f01d-e947-4944-9e20-c89977b78424',
#    '5d2199a6-cc9e-4085-bdf4-7d7deeb68191']],
#  'embeddings': None,
#  'documents': [['building test mvc5 controller method use moq test interested test controller method require authentication us userid value username value make decision data show browserclient research far considerable amount code available moq username much code userid value case look like guid use aspnet identity account management owin add well google facebook login use dependency injection use unity seem way accomplish test plus di enables use moq example test method look notnull return controller method getcurrentuserid method query useridentity object userid use code method supposedly get replace moq getcurrentuserid method virtual method helper class myhelper parameter constructor model object modelobject parameter constructor controller examplecontroller happens debugger visual studio 2013 test method object create createmodelobjectfromhelper method examplecontroller create line myhelper moqd object becomes null see object value statement statement myhelper object becomes nulland whole test fails assume fails difficult call method object null question iswhat cause object become null question ismaybe well way id sure glad hear suggestion thank work like try create mock mock mock controller depend imodelobject create mock set propertiesmethods return need controller without code imodelobject use controller hard provide well example',
#    'test view cooky create firebug browser tool log cooky create define cookie authentication startupcs use identity framework checked indentified source create login actionresult controlleraccountcontrollercs login model modelloginmodelcs login viewaccountlogincshtml password controller create cookie controlleraccountcontrollercs modelloginmodel startupcs viewlogincshtml see answer may need add claim applicationusergenerateuseridentityasync method',
#    'write test case action filter use form authentication base controller decorate requiresauthentication action filter execute controller test case get loggedin user data cooky use moq provide way achieve goal blog post scott hanselmann cover mvcmockhelpers include different mock framework among others also moq another good resource aspnet mvc test helper mvccontrib project codeplex test action filter',
#    'currently write unit test check functionality correct working asp mvc application write mvc application use special actionfilterattribute allows authentication make request mvc application code actionfilterattribute problem currently face seem properly mock section response header write unittest mock httprequest httpresponse object call attribute function request follow successful login path branch code iis7 simulation relies property try follow iis6 branch login get null pointer exception use follow code construct moq object actuall test look like last assert fail header beeing set use debugger step code filter actually set header think moq object properly configure handle request could someone please shed light get httpresponse accept headersadd request seem found add follow line setup delegate call moq implementation rather simple know',
#    'write first unit test question say test test pass understand however web page actually work expect view cannot found think please correct wrong need write another test validate view render correctly know test view render correctly test controller action return viewresult try think like say youll need mock dependency controller need data access etc also http context controller intend live library make pretty easy here another stack overflow question may help mock httpcontext aspnet mvc use moq']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'Id': 28734300,
#     'Score_answer': 1,
#     'ParentId': 28734300,
#     'Title': 'moq object becomes null after assignment to controller',
#     'Score_question': 0,
#     'CreationDate_question': '2015-02-26T04:08:36Z'},
#    {'Score_answer': 0,
#     'ParentId': 29922830,
#     'Score_question': 0,
#     'Title': "Hardcoded ClaimIdentity doesn't create a cookie",
#     'Id': 29922830,
#     'CreationDate_question': '2015-04-28T14:59:18Z'},
#    {'Title': 'ASP.NET MVC test for action filters',
#     'CreationDate_question': '2010-12-15T12:17:32Z',
#     'Id': 4449770,
#     'Score_answer': 2,
#     'ParentId': 4449770,
#     'Score_question': 2},
#    {'Id': 4732870,
#     'ParentId': 4732870,
#     'Title': 'Mocking HttpRequest and HttpResponse for MVC Application',
#     'Score_answer': 8,
#     'CreationDate_question': '2011-01-19T07:43:38Z',
#     'Score_question': 12},
#    {'CreationDate_question': '2014-07-03T22:15:41Z',
#     'Score_question': 0,
#     'ParentId': 24564070,
#     'Title': 'How Can I Test That My View Is Rendered Correctly?',
#     'Id': 24564070,
#     'Score_answer': 1}]],
#  'distances': [[0.30920445919036865,
#    0.34033703804016113,
#    0.3459053635597229,
#    0.3514443039894104,
#    0.3617299795150757]]}

# %%
# Пример поиска
# Похожий вопрос, но не тот же самый
# Результат - 5 ответ
query = "I am making a experiment for an MVC5 controller case.  I'm using moq for the experiment.  What I'm fond of is how to experiment a control method that require"
top_results = semantic_search(query, top_k=5)
top_results
# Out:
# {'ids': [['415e6865-6f68-4b2a-bdf2-976b07daf20a',
#    '5447d40c-b285-4b9a-8beb-8a3fc1320d60',
#    'fbd4bb30-e6f4-48bc-b9eb-e4ae957cc5c5',
#    'a3c365bb-79e4-4f0c-acb6-3ec1a47d4b36',
#    '6eed49f7-c4c5-44af-a3bb-2450d2ca0e03']],
#  'embeddings': None,
#  'documents': [['here scenario work net mvc 40 project repository youd expect try implement moqxunit test library net unit test project get far mvc controller unit test class problem controller call directly everything work fine 100 policy load however run test 0 product load guess problem mock call somewhere line potentially service initialisation anyone ever offer advice also correct test service rather repository held data layer thanks advance test code initialize empty list tell mock service return empty list make test load policy need put policy instance list would write test look something like really depends aspect code try unit test see test simply confirms store policy object expect might write test logic depends policy instance',
#    'attempt mock controller session variable use moq keep run session visible test null inside actual controller test code controller code code follow common pattern see several posting mvc 2 action ch 7 example etc still work inside controller controllercontext null httpcontext wrong must configuration issue cause add unit test project alreadyexisting project create new mvc 3 project checked create unit test project add controller model etc old project new one work fine',
#    'new moq try test controller mvc behaviour view raise certain event controller call certain function model class test issue test fail second last line another thing notice test terminates second last line last line never execute everything correct please find work snippet difference declare virtual reason moq creates runtime wrapper class override beheviour method virtual impossible',
#    'certain controller action mvc4 web application use response object access query string variable among thing whats best practice abstract away interfere unit test action mvc4 team make related property abstract mocked type already abstract away mock call standard method use past initialise controller unit test scenario respect moq create fake http context mock various related property require modify fit exact scenario instantiate controller pas method perhaps base class use nbehave unit test wont muddy water anything related specifically mock set recently write blog post cover approach use mock framework instead unit test controller use nunit nsubstitute',
#    'building test mvc5 controller method use moq test interested test controller method require authentication us userid value username value make decision data show browserclient research far considerable amount code available moq username much code userid value case look like guid use aspnet identity account management owin add well google facebook login use dependency injection use unity seem way accomplish test plus di enables use moq example test method look notnull return controller method getcurrentuserid method query useridentity object userid use code method supposedly get replace moq getcurrentuserid method virtual method helper class myhelper parameter constructor model object modelobject parameter constructor controller examplecontroller happens debugger visual studio 2013 test method object create createmodelobjectfromhelper method examplecontroller create line myhelper moqd object becomes null see object value statement statement myhelper object becomes nulland whole test fails assume fails difficult call method object null question iswhat cause object become null question ismaybe well way id sure glad hear suggestion thank work like try create mock mock mock controller depend imodelobject create mock set propertiesmethods return need controller without code imodelobject use controller hard provide well example']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'Title': '.NET Unit Testing - Moq/xUnit frameworks with MVC, not returning expected results',
#     'CreationDate_question': '2012-11-19T09:27:42Z',
#     'Id': 13450870,
#     'ParentId': 13450870,
#     'Score_answer': 2,
#     'Score_question': 2},
#    {'Id': 5174400,
#     'CreationDate_question': '2011-03-02T22:36:48Z',
#     'ParentId': 5174400,
#     'Score_answer': 0,
#     'Title': 'Mocking a session in MVC 3',
#     'Score_question': 2},
#    {'Title': 'Test MVC using moq',
#     'Score_answer': 2,
#     'Id': 2707200,
#     'CreationDate_question': '2010-04-25T04:53:24Z',
#     'Score_question': 0,
#     'ParentId': 2707200},
#    {'Title': 'How to Abstract away the Response object in MVC4 for Testing?',
#     'ParentId': 15752640,
#     'Score_answer': 5,
#     'Id': 15752640,
#     'Score_question': 3,
#     'CreationDate_question': '2013-04-01T21:58:06Z'},
#    {'Score_answer': 1,
#     'Id': 28734300,
#     'ParentId': 28734300,
#     'Score_question': 0,
#     'Title': 'moq object becomes null after assignment to controller',
#     'CreationDate_question': '2015-02-26T04:08:36Z'}]],
#  'distances': [[0.4303121566772461,
#    0.4494524598121643,
#    0.4516364336013794,
#    0.4573547840118408,
#    0.4586958885192871]]}

# %%
# Пример поиска
# Лучший ответ совпал с 4 лабой - правильный ответ
query = r"""<p>Would this be classified as an O(1) algorithm for "Hello, World!" ??</p>"""
top_results = semantic_search(query, top_k=5)
top_results
# Out:
# {'ids': [['9dc09d8e-8623-4fae-ac5e-541a60e0d83b',
#    '04258003-aaa6-4a2a-a02e-03a9b890ab81',
#    '681857a7-c8b3-4412-b933-f79589bb95eb',
#    '3d7daa24-b5da-49e4-a071-24fe6d252747',
#    '3af968e9-f41e-452c-a7f8-6a94c2ffba16']],
#  'embeddings': None,
#  'documents': [['would classify o1 algorithm think use snippet code busy loop put joke whenever someone asks algorithm certain complexity would correct big notation context use describe relationship size input function number operation need perform compute result input operation input output related use big notation nonsensical time operation take independent input operation isnone since relationship input number operation perform use big describe nonexistent relationship',
#    'formulate algorithm problem analyse o2mn suppose get omn want know o2mn omn yes big ignores constant',
#    'building intent recognition system use multiclass classfication svm currently number class limited training data however future may get data new class course put data together retrain model timing consume inefficient current idea oneagainstone classification begin new class come train exist class get n new classifier wonder well method thanks efficient approach would focus oneclass classifier need add one new model ensemble compare let u assume k class get 1 new plus p new point whole dataset consists n point simpliciy equaly distribute among class training algorithm complexity classifier support incremental learn complexity ovo one v one order get exact result need train k new classifier nk datapoints thus lead place use incremental training ovum one v order get exact result retrain classifier do batch fassion need bad however train incremental fashion need might well depend classifier oneclass ensemble might seem bit weird example naive bayes see approach generative model model class conditional distribution thus model class actually independent remain one thus complexity list obviously exhaustive give general idea analyze',
#    'complexity mention right yes please explain detail outer loop executes n 2 time inner loop executes n 2 2 time ignore truncation effect integer division complexity on2 assume o1 arithmetic operation',
#    'decision tree one usually determine observation instance outcomeclass eg sunshine rain wonder data mining algorithm group instance base attribute determines class example case could instance use play outlook outcomeclass question algorithm method would tell instance outlook attribute could use outcomeclass obviously continuous attribute work discrete attribute could work question want would computer program know tell output input program course apply heuristic ie attribute name us special type automatically chosen output remainder input']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'Title': 'Is this technically an O(1) algorithm for "Hello World"?',
#     'Score_answer': 391,
#     'CreationDate_question': '2015-12-02T17:06:54Z',
#     'Score_question': 114},
#    {'Score_question': 0,
#     'Score_answer': 3,
#     'Title': 'Big Oh Analysis Result',
#     'CreationDate_question': '2016-02-11T05:47:30Z'},
#    {'CreationDate_question': '2015-12-10T14:40:50Z',
#     'Title': 'Multiclass classification growing number of classes',
#     'Score_question': 0,
#     'Score_answer': 0},
#    {'Score_question': 0,
#     'Score_answer': 0,
#     'Title': 'How this program has time complexity Big Oh (n^2logn)?',
#     'CreationDate_question': '2015-07-03T17:34:29Z'},
#    {'Score_answer': 0,
#     'Score_question': 0,
#     'Title': 'Any method to determine class of an instances?',
#     'CreationDate_question': '2013-05-16T08:43:31Z'}]],
#  'distances': [[0.258639931678772,
#    0.4773043394088745,
#    0.5129150748252869,
#    0.5228264331817627,
#    0.5276705622673035]]}

# %%
# Пример поиска
# Похожий вопрос, но не тот же самый
# Результат - 1 ответ
query = r"""Can it be categorized as an O(1) algorithm for "Hi, World!"""
top_results = semantic_search(query, top_k=5)
top_results
# Out:
# {'ids': [['3f9945e7-74db-409d-bc99-a519fca89a41',
#    '7cd2edef-4f2d-4242-946a-359ccd0fd59f',
#    '0f4109d3-e570-4ec5-8015-2cf1f69c1594',
#    '9ccb80fe-f41e-4663-8a92-e473199c3c9e',
#    '3ff2947e-2647-4180-9c14-c50146e3417a']],
#  'embeddings': None,
#  'documents': [['would classify o1 algorithm think use snippet code busy loop put joke whenever someone asks algorithm certain complexity would correct big notation context use describe relationship size input function number operation need perform compute result input operation input output related use big notation nonsensical time operation take independent input operation isnone since relationship input number operation perform use big describe nonexistent relationship',
#    'selfstudy bigo understand give example follow notation algorithm on2 on3 come across notation quite comprehend give example term algorithm maybe phrase way write algorithm take run time proportion on34 log n3 olog2non 4n n32 fear misunderstand notation notation algorithm rather bigo notation describes property algorithm rather say quite reasonable ask example algorithm certain complexity already list address question o4n oen often write oexpn try understand o4n belongs class algorithm exptime many important problem mathcs exponential complexity nearly exponential complexity algorithm exponential complexity would example naive solution discrete logarithm problem complexity cannot give example probably find one google bit',
#    'formulate algorithm problem analyse o2mn suppose get omn want know o2mn omn yes big ignores constant',
#    'naive one one olog n even o1 sort array use binary search tree array size n 2 h 1 1 hheight complete binary tree unsorted array sort well proof suppose look every single element array adversary could make one element look large small give number make count incorrect well possible sort array sort determine result olog n time locate first element great equal give number simply subtract index size array',
#    'quite understand olog n near neighbor algorithm wikipedia algorithm unwinds recursion tree perform follow step node algorithm check whether could point side splitting plane closer search point current best concept do intersect splitting hyperplane hypersphere around search point radius equal current near distance since hyperplanes axisaligned implement simple comparison see whether difference splitting coordinate search point current node less distance overall coordinate search point current best hypersphere cross plane could nearer point side plane algorithm must move branch tree current node look closer point follow recursive process entire search hypersphere intersect splitting plane algorithm continue walk tree entire branch side node eliminate 32 confuse see question implement algorithm java sure get right code accomplish 32 aspect algorithm specifically populate variable find full source code kdtree thanks helppointers add hop help others search problem end address 32 follow code although sure 100 correct pass test come original code fail number test case explicit solution use point line rectangle cube object think simpler code also work pass test code']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'CreationDate_question': '2015-12-02T17:06:54Z',
#     'ParentId': 34048740,
#     'Title': 'Is this technically an O(1) algorithm for "Hello World"?',
#     'Score_answer': 391,
#     'Score_question': 114,
#     'Id': 34048740},
#    {'ParentId': 4012860,
#     'CreationDate_question': '2010-10-25T08:19:53Z',
#     'Score_answer': 9,
#     'Score_question': 2,
#     'Title': 'Big-O time complexity',
#     'Id': 4012860},
#    {'Score_answer': 3,
#     'Score_question': 0,
#     'CreationDate_question': '2016-02-11T05:47:30Z',
#     'Id': 35331700,
#     'ParentId': 35331700,
#     'Title': 'Big Oh Analysis Result'},
#    {'Score_answer': 8,
#     'Title': 'How many numbers in an array are smaller than a given number?',
#     'ParentId': 2710770,
#     'Score_question': 2,
#     'Id': 2710770,
#     'CreationDate_question': '2010-04-26T02:18:09Z'},
#    {'Title': 'KD Tree - Nearest Neighbor Algorithm',
#     'Score_answer': 1,
#     'Id': 11209040,
#     'ParentId': 11209040,
#     'CreationDate_question': '2012-06-26T14:00:37Z',
#     'Score_question': 1}]],
#  'distances': [[0.27020686864852905,
#    0.47860169410705566,
#    0.48074132204055786,
#    0.49573880434036255,
#    0.5040303468704224]]}

# %%
# Пример поиска
# Лучший ответ совпал с 4 лабой - правильный ответ
query = r"""I cannot get iOS 6 to play any sound at all using the Web Audio API with examples that work fine in desktop Chrome."""
top_results = semantic_search(query, top_k=5)
top_results
# Out:
# {'ids': [['6e440527-e7f1-4adf-8d69-c034f391bc71',
#    '02c774f0-3e91-4f92-a766-8f43e3c3c207',
#    'db586ec7-4bc9-4dc3-b918-2547dd282752',
#    '4acc7c9e-f4a0-4e53-b2ac-f19d29bb4542',
#    '361cf918-0373-4cd6-a763-c19a1d887169']],
#  'embeddings': None,
#  'documents': [['really excite see io 6 support web audio api since make html5 game however cannot get io 6 play sound use web audio api example work fine desktop chrome html5 game touch control play audio via web audio api present fall back html5 audio httpwwwscirracomlabssbios6b edit srikumar suggest workarounds apply version still work httpwwwscirracomlabssbios6f everything play fine desktop chrome io 6 emits sound trouble debug window development io 6 replace debug mode remote web inspector apparently available safari window use alert find correctly identifies web audio api us detects vorbis support fall back aac audio decodes buffer play error thrown hear nothing course try turn volume max codec problem io 6 play aac fine browse one m4as game play play fine visit direct safari look web audio api example io 6 httpchromiumgooglecodecomsvntrunksamplesaudiosampleshtml work others example chrome audio visualizer work javascript drone must subtle incompatibility web audio io 6 desktop chrome miss edit november 2015 io 9 longer allows audio start event break solution however work event original answer io 6 left intact io 9 support make sure use well sorry answer bounty question hour debug finally found answer safari io 6 effectively start web audio api mute unmute attempt play sound user input event create buffer source connect destination call unmutes audio play unrestricted ought undocumented aspect web audio api work io 6 apple doc hopefully update mention soon user touch screen lot engage game remain mute play inside user input event like edit io 9 audio unmutes play audio time user input event note different restriction html5 audio typically start audio user input event play one sound time web audio api fully unmutes first playinuserinput play sound time mix polyphonically process cool effect etc mean many game already web use web audio api never play audio happen issue noteon touch event adjust wait first user input event way work around play title music user touch screen initial touch enable audio screen play sound begin game touch etc hopefully help anyone else problem save time try debug',
#    'say web audio api work chrome android test cm browser chrome cyanogenmod default android 511 browser pas test specially biquadnode one open codepen eq biquadnode hear music eq work biquadnode work android special implementation need code pen require post chrome android work general recent build chrome 49 later go enable unified medium pipeline option make work like desktop',
#    'problem play sound ieff safari chrome work want play sound click canvas two sound sound work google chrome indexphp gamejs work chrome firefox ie safari idea',
#    'developed web app want package desktop application use framework try appjs tidesdk everything work fine except one function play sound audio element button play sound function play sound everything work fine test stuff browser sound play publish app use framework audio file mp3 format think format support framework since base webkit please help use html5 play sound automatic part chromium appjs us quick fix use soundmanager2 play audio instead detects available us various fallback appjs select flash fallback longer fix distribute extra binary appjs enables audio cannot remember exactly call time future html5 standard support box',
#    'use audiocontext web audio api install chrome beta 29 version android 40 tabletsamsung p7510 javascript throw exception chrome beta 29 pc version work fine even test cell phone ok try context new audiocontext']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'Score_answer': 45,
#     'Id': 12517000,
#     'Title': 'No sound on iOS 6 Web Audio API',
#     'CreationDate_question': '2012-09-20T16:34:02Z',
#     'ParentId': 12517000,
#     'Score_question': 35},
#    {'Id': 36779910,
#     'Score_answer': 0,
#     'ParentId': 36779910,
#     'CreationDate_question': '2016-04-21T20:34:09Z',
#     'Score_question': 0,
#     'Title': 'Web Audio Api biquadFilter in Android needs extra configuration?'},
#    {'Score_question': 0,
#     'Id': 28670720,
#     'Score_answer': 0,
#     'CreationDate_question': '2015-02-23T09:41:15Z',
#     'Title': 'JavaScript Sounds on ClickEvent works only on google chrome',
#     'ParentId': 28670720},
#    {'Score_answer': 3,
#     'Title': 'Sound not playing in appJS and tideSDK',
#     'Score_question': 0,
#     'Id': 13987490,
#     'ParentId': 13987490,
#     'CreationDate_question': '2012-12-21T09:30:34Z'},
#    {'CreationDate_question': '2013-08-01T08:18:41Z',
#     'Score_answer': 0,
#     'Title': 'AudioContext of Web Audio API is not exist in Chrome beta 29 of Android 4.0 tablet',
#     'ParentId': 17988630,
#     'Score_question': 1,
#     'Id': 17988630}]],
#  'distances': [[0.32290762662887573,
#    0.3245888948440552,
#    0.33554017543792725,
#    0.3377993106842041,
#    0.3506019115447998]]}
